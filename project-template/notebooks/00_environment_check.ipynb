# %% [markdown]
# # 00. CAL ML Environment Check
# Terraform이 자동 구성한 EC2/Jupyter/PyTorch/GPU/S3 환경을 확인하는 첫 Notebook입니다.

# %%
import os, sys, platform
print('Python:', sys.version)
print('Platform:', platform.platform())
print('Project:', os.getenv('CAL_PROJECT_DIR'))
print('Cache:', os.getenv('CAL_CACHE_DIR'))
print('S3 Bucket:', os.getenv('CAL_S3_BUCKET'))

# %%
import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('VRAM GiB:', round(torch.cuda.get_device_properties(0).total_memory / 1024**3, 1))

# %% [markdown]
# ## 다음 단계
# GPU가 정상 인식되면 실제 데이터 일부를 `/workspace/cache`에 내려받아 batch size와 1 epoch 시간을 먼저 측정합니다.
